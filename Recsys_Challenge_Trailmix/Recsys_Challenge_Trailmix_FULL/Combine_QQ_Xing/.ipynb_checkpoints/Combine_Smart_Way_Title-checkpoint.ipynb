# %%
import json
import numpy as np
import operator
import math

# %%
def r_precision(G, R):
    limit_R = R[:len(G)]
    if len(G) != 0:
        return len(list(set(G).intersection(set(limit_R)))) * 1.0 / len(G)
    else:
        return 0

def ndcg(G, R):
    r = [1 if i in set(G) else 0 for i in R]
    r = np.asfarray(r)
    dcg = r[0] + np.sum(r[1:] / np.log2(np.arange(2, r.size + 1)))
    #k = len(set(G).intersection(set(R)))
    k = len(G)
    if k > 0:
        idcg = 1 + np.sum(np.ones(k - 1) / np.log2(np.arange(2, k + 1)))
        return dcg * 1.0 / idcg
    else:
        return 0

def clicks(G, R):
    n = 1
    for i in R:
        if i in set(G):
            return ((n - 1) / 10) * 1.0
        n += 1
    return 51

# %%
GT = json.load(open('../DATA_PROCESSING/PL_TRACKS_ALL.json'))
# GT = json.load(open('../DATA_PROCESSING/PL_TRACKS_5_TEST.json'))
track_index = json.load(open('../DATA_PROCESSING/ALL_INDEX_READONLY/TRACK_INDEX_READONLY.json'))
track_index_reversed = {k:v for (v, k) in track_index.items()}

# %%
pl_title = json.load(open('../MODEL_1_PL_NAME_NEW/PID_PROCESSED_TITLE_LIST_PROCESSED.json'))

# %%
pl_title
# Out:
# {u'287144': [u'god'],
#  u'287145': [u'musica'],
#  u'287146': [u'feel'],
#  u'287147': [u'aye'],
#  u'287140': [u'feel', u'good'],
#  u'287141': [u'white', u'peopl'],
#  u'287142': [u'emma'],
#  u'287143': [u'love'],
#  u'287148': [u'controlla'],
#  u'287149': [u'chillstep'],
#  u'378468': [u'sunday'],
#  u'378469': [u'feel', u'good', u'inc'],
#  u'89370': [u'workout'],
#  u'89371': [u'poetic', u'justic'],
#  u'89372': [u'car', u'playlist'],
#  u'89373': [u'best', u'hit'],
#  u'89374': [u'tvd'],
#  u'89375': [u'good', u'mix'],
#  u'89376': [u'winter', u'come'],
#  u'89377': [u'edm'],
#  u'89378': [u'80'],
#  u'89379': [u'chill'],
#  u'378463': [u'gym'],
#  u'778286': [u'current'],
#  u'778287': [u'golden'],
#  u'778284': [],
#  u'778285': [u'kickback'],
#  u'778282': [u'turnip'],
#  u'378460': [u'remind'],
#  u'778280': [u'rap', u'god'],
#  u'778281': [u'guilti', u'pleasur'],
#  u'968454': [u'chill'],
#  u'968455': [u'summer', u'day'],
#  u'968456': [u'supernatur'],
#  u'378461': [u'papi'],
#  u'968450': [u'yaaa'],
#  u'968451': [u'samba'],
#  u'778288': [u'thursday'],
#  u'778289': [u'jesu'],
#  u'978808': [u'soft'],
#  u'978809': [u'road', u'trippin'],
#  u'958439': [u'purpl'],
#  u'978802': [u'swole'],
#  u'978803': [u'aux'],
#  u'978800': [u'march', u'2017'],
#  u'978801': [u'wed'],
#  u'978806': [u'naija'],
#  u'978807': [u'danc'],
#  u'978804': [u'lilli'],
#  u'978805': [u'top', u'song'],
#  u'391271': [u'darti'],
#  u'730842': [u'wed'],
#  u'958438': [u'morn'],
#  u'494928': [u'studi', u'time'],
#  u'494929': [u'im', u'love'],
#  u'194554': [u'jazz'],
#  u'970848': [u'classic'],
#  u'825671': [u'countri'],
#  u'494920': [u'emo', u'music'],
#  u'494921': [u'roadtrippin'],
#  u'494922': [u'glori'],
#  u'494923': [u'blossom'],
#  u'494924': [u'mainstream'],
#  u'494925': [u'dee'],
#  u'494926': [u'love'],
#  u'494927': [u'arg'],
#  u'825673': [u'sb2k16'],
#  u'825674': [u'nine'],
#  u'825675': [u'favorit', u'song'],
#  u'780919': [u'car', u'ride'],
#  u'780918': [u'pep', u'ralli'],
#  u'825676': [u'march'],
#  u'780911': [u'daili', u'mix'],
#  u'780910': [u'old', u'school', u'countri'],
#  u'780913': [u'rap'],
#  u'780912': [u'best', u'playlist', u'ever'],
#  u'780915': [u'old', u'school'],
#  u'780914': [u'old', u'school'],
#  u'780917': [u'countri'],
#  u'780916': [u'inferno'],
#  u'827210': [u'lit'],
#  u'73622': [u'partyy', u'unknown'],
#  u'316996': [u'lit', u'af'],
#  u'494312': [u'old', u'skool', u'hip', u'hop'],
#  u'316994': [u'new', u'find'],
#  u'825155': [u'girl'],
#  u'101359': [u'moana'],
#  u'545969': [u'homeward', u'bound'],
#  u'545968': [u'2015'],
#  u'545965': [u'hb'],
#  u'545964': [u'playlist'],
#  u'545967': [u'mom'],
#  u'545966': [u'beau'],
#  u'545961': [u'parti', u'time'],
#  u'545960': [u'sauconi', u'steadi', u'playlist'],
#  u'545963': [u'classic'],
#  u'545962': [u'housewarm'],
#  u'494315': [u'unknown', u'12'],
#  u'316991': [u'reg'],
#  u'80276': [u'bday'],
#  u'80277': [u'nf'],
#  u'968458': [u'21'],
#  u'494319': [u'jam'],
#  u'778283': [u'music'],
#  u'554376': [u'folk'],
#  u'554377': [u'summer', u'playlist'],
#  u'554374': [u'repeat'],
#  u'554375': [u'track'],
#  u'554372': [u'old', u'school'],
#  u'554373': [u'hype'],
#  u'554370': [u'unknown'],
#  u'554371': [u'bet'],
#  u'80272': [u'random', u'favorit'],
#  u'554378': [u'2015'],
#  u'554379': [u'bay', u'area'],
#  u'316998': [u'rhapsodi'],
#  u'80271': [u'chill'],
#  u'168083': [u'ooooo'],
#  u'168082': [u'italian'],
#  u'168081': [u'raini', u'day'],
#  u'168080': [u'think', u'loud'],
#  u'168087': [u'parti'],
#  u'168086': [u'lili'],
#  u'168085': [u'love'],
#  u'168084': [u'funni'],
#  u'168089': [u'life'],
#  u'168088': [u'yin'],
#  u'968452': [u'90', u'jam'],
#  u'958988': [],
#  u'968453': [u'mix'],
#  u'909073': [u'ladi', u'jam'],
#  u'719203': [u'feel'],
#  u'719202': [u'mood'],
#  u'719201': [u'oldi'],
#  u'719200': [u'slow', u'down'],
#  u'719207': [u'us'],
#  u'719206': [u'oldi'],
#  u'719205': [u'ambient'],
#  u'719204': [u'classic', u'rock'],
#  u'926661': [u'punk'],
#  u'926660': [u'sleep'],
#  u'719209': [u'countri'],
#  u'719208': [u'5k'],
#  u'926665': [u'2016'],
#  u'926664': [u'like'],
#  u'926667': [u'countri', u'playlist'],
#  u'926666': [u'hotel', u'california'],
#  u'312489': [u'oldi'],
#  u'958430': [u'throwback'],
#  u'163509': [u'sweet', u'16'],
#  u'163508': [u'pregam'],
#  u'163507': [u'summer', u'2015'],
#  u'163506': [u'cumbia'],
#  u'163505': [u'fave'],
#  u'163504': [u'studi'],
#  u'163503': [u'normal'],
#  u'163502': [u'becaus'],
#  u'163501': [u'zzzz'],
#  u'163500': [u'rememb'],
#  u'513058': [u'neosoul'],
#  u'513059': [u'septemb', u'2016'],
#  u'513052': [u'favorit', u'song'],
#  u'513053': [u'spanish', u'jam'],
#  u'513050': [u'saturday'],
#  u'513051': [u'worship'],
#  u'513056': [u'bluegrass'],
#  u'513057': [u'food'],
#  u'513054': [u'parti', u'parti'],
#  u'513055': [u'goodi'],
#  u'780301': [u'favorit'],
#  u'919761': [u'parti'],
#  u'828185': [u'song'],
#  u'828184': [u'coffe'],
#  u'828187': [u'bump', u'n', u'grind'],
#  u'828186': [u'high', u'school', u'music'],
#  u'828181': [u'salsa'],
#  u'828180': [u'90'],
#  u'828183': [u'mood'],
#  u'828182': [u'summer', u'festiv', u'playlist'],
#  u'780304': [u'bonnaroo'],
#  u'828189': [u'sexi'],
#  u'828188': [u'new', u'countri'],
#  u'780305': [u'drake'],
#  u'584445': [u'spanish'],
#  u'584444': [u'run'],
#  u'584447': [u'coachella', u'2014'],
#  u'584446': [u'late'],
#  u'584441': [u'anti'],
#  u'584440': [u'yuhhh'],
#  u'584443': [u'wed', u'danc'],
#  u'584442': [u'jesu', u'music'],
#  u'795646': [u'sunday'],
#  u'584449': [u'boom'],
#  u'584448': [u'shake'],
#  u'780308': [u'aj'],
#  u'909077': [u'chill'],
#  u'780309': [u'cruis'],
#  u'353851': [u'xy'],
#  u'634197': [u'best', u'best'],
#  u'353528': [u'spoken', u'word'],
#  u'795644': [u'altern'],
#  u'227611': [u'va'],
#  u'303231': [u'aesthet'],
#  u'303230': [u'poni'],
#  u'303233': [u'workout', u'2'],
#  u'303232': [u'work'],
#  u'303235': [u'chill', u'vibe'],
#  u'303234': [u'hood'],
#  u'303237': [u'danc'],
#  u'303236': [u'road', u'trip'],
#  u'303239': [u'chang'],
#  u'303238': [u'chill', u'vibe'],
#  u'958437': [u'februari'],
#  u'388670': [u'right'],
#  u'388671': [u'sticki'],
#  u'388672': [u'obsess'],
#  u'388673': [u'groovi'],
#  u'388674': [u'jam'],
#  u'388675': [u'wordless'],
#  u'388676': [u'dad'],
#  u'388677': [u'warmup'],
#  u'388678': [u'count', u'star'],
#  u'388679': [u'new', u'soul'],
#  u'795642': [u'new', u'stuff'],
#  u'89589': [u'rock'],
#  u'532444': [u'current'],
#  u'532445': [u'throwback'],
#  u'532446': [u'emo'],
#  u'532447': [u'brasil'],
#  u'532440': [u'run'],
#  u'532441': [u'summer'],
#  u'532442': [u'pump', u'up'],
#  u'532443': [u'throwback'],
#  u'532448': [u'tierra', u'calient'],
#  u'532449': [u'hip', u'hop'],
#  u'257655': [u'studio'],
#  u'257654': [u'og', u'rap'],
#  u'257657': [u'summer', u'2014'],
#  u'257656': [u'hannah', u'montana'],
#  u'257651': [u'uber'],
#  u'257650': [u'flex'],
#  u'257653': [u'jam'],
#  u'257652': [u'car'],
#  u'257659': [u'whoop'],
#  u'257658': [u'road'],
#  u'89583': [u'old', u'fav'],
#  u'634196': [u'fav', u'song'],
#  u'89582': [u'stuff'],
#  u'89581': [u'drive'],
#  u'89580': [u'rock'],
#  u'958982': [u'pretti'],
#  u'89587': [u'chill'],
#  u'89586': [u'yoga', u'1'],
#  u'89585': [u'music'],
#  u'184924': [u'car', u'banger'],
#  u'89584': [u'idk'],
#  u'227616': [u'chill'],
#  u'381725': [u'lit'],
#  u'381724': [u'depress'],
#  u'381727': [u'happi', u'day'],
#  u'381726': [u'summer', u'jam'],
#  u'381721': [u'disney'],
#  u'381720': [u'imagin', u'dragon'],
#  u'26568': [u'cappella'],
#  u'26569': [u'aug'],
#  u'26566': [u'jam'],
#  u'26567': [u'logic', u'unknown', u'incred', u'true', u'stori'],
#  u'26564': [u'white', u'girl'],
#  u'26565': [u'countri', u'jam'],
#  u'26562': [u'2017'],
#  u'26563': [u'sssss'],
#  u'26560': [u'sarah', u'playlist'],
#  u'26561': [u'feel'],
#  u'609988': [u'2014', u'playlist'],
#  u'609989': [u'dark'],
#  u'609982': [u'cocktail', u'hour'],
#  u'609983': [u'car'],
#  u'609980': [u'immort'],
#  u'609981': [u'quiet'],
#  u'609986': [u'worship'],
#  u'609987': [u'memphi'],
#  u'609984': [u'parti', u'mix'],
#  u'609985': [u'danc'],
#  u'150169': [u'countri'],
#  u'150168': [u'game'],
#  u'150167': [u'shake'],
#  u'150166': [u'funki'],
#  u'150165': [u'jazz'],
#  u'150164': [u'begin', u'again'],
#  u'150163': [u'countri'],
#  u'150162': [u'new', u'countri'],
#  u'150161': [u'countri', u'vibe'],
#  u'150160': [u'clean'],
#  u'73335': [u'funk'],
#  u'831619': [u'cool', u'jazz'],
#  u'572080': [u'song'],
#  u'572081': [u'beach'],
#  u'572082': [u'glee'],
#  u'572083': [u'damn'],
#  u'572084': [u'whatev'],
#  u'572085': [u'clout'],
#  u'572086': [u'andi'],
#  u'572087': [u'popular'],
#  u'572088': [u'chanc', u'rapper'],
#  u'572089': [u'want', u'christma'],
#  u'296200': [u'trap'],
#  u'654858': [u'parti', u'playlist'],
#  u'123277': [u'salsa'],
#  u'355068': [u'countri', u'1'],
#  u'670399': [u'blah'],
#  u'670398': [u'get', u'down'],
#  u'670397': [u'countri'],
#  u'670396': [u'par'],
#  u'670395': [u'workout', u'playlist'],
#  u'670394': [u'new', u'summer'],
#  u'670393': [u'edm', u'mix'],
#  u'670392': [u'tango'],
#  u'670391': [u'disney'],
#  u'670390': [u'march', u'2015'],
#  u'773139': [u'pool', u'parti'],
#  u'773138': [u'good'],
#  u'773135': [u'think', u'music'],
#  u'773134': [u'vibe'],
#  u'773137': [u'workout', u'jamz'],
#  u'773136': [u'oldi'],
#  u'773131': [u'septemb'],
#  u'773130': [u'countri'],
#  u'773133': [u'jam'],
#  u'773132': [u'car'],
#  u'581165': [u'pop', u'latino'],
#  u'581164': [u'autumn'],
#  u'581167': [u'groovin'],
#  u'581166': [u'star'],
#  u'581161': [u'motown'],
#  u'581160': [u'oldi', u'goodi'],
#  u'581163': [u'xx'],
#  u'581162': [u'pregam'],
#  u'581169': [u'futur', u'hous'],
#  u'581168': [u'awesom', u'playlist'],
#  u'105639': [u'playlist'],
#  u'105638': [u'kesha'],
#  u'446861': [u'chilll'],
#  u'105631': [u'best', u'day', u'ever'],
#  u'105630': [u'cruis'],
#  u'105633': [u'littl', u'bit', u'countri'],
#  u'105632': [u'spring', u'17'],
#  u'105635': [u'salsa', u'mix'],
#  u'105634': [u'countri'],
#  u'105637': [u'lit'],
#  u'105636': [u'slow', u'song'],
#  u'309428': [u'dreami'],
#  u'309429': [u'good', u'time'],
#  u'309422': [u'blah'],
#  u'309423': [u'good', u'rap'],
#  u'309420': [u'sleep'],
#  u'309421': [u'electro', u'chill'],
#  u'309426': [u'drake'],
#  u'309427': [u'nueva', u'lista', u'2'],
#  u'309424': [u'unknown'],
#  u'309425': [u'throwback'],
#  u'351690': [u'prais'],
#  u'351691': [u'50'],
#  u'351692': [u'practic'],
#  u'351693': [u'xma'],
#  u'351694': [u'feel'],
#  u'351695': [u'classic'],
#  u'351696': [u'rb'],
#  u'351697': [u'soca'],
#  u'351698': [u'saturday'],
#  u'351699': [u'main', u'music'],
#  u'879024': [u'autumn'],
#  u'879025': [u'church', u'song'],
#  u'879026': [u'disney'],
#  u'879027': [u'oldi'],
#  u'879020': [u'classic'],
#  u'879021': [u'music'],
#  u'879022': [u'car', u'ride'],
#  u'879023': [u'indi', u'mix'],
#  u'879028': [u'feel', u'good'],
#  u'879029': [u'classic'],
#  u'386845': [u'run'],
#  u'386844': [u'pump', u'up'],
#  u'386847': [u'pregam'],
#  u'386846': [u'throwback'],
#  u'386841': [u'tbt'],
#  u'386840': [],
#  u'386843': [u'time'],
#  u'386842': [u'gym', u'mix'],
#  u'929945': [u'f', u'e', u'e', u'l'],
#  u'929944': [u'summer'],
#  u'929947': [u'lit'],
#  u'929946': [u'inspir'],
#  u'386849': [u'gym'],
#  u'386848': [u'richard'],
#  u'929943': [u'steven'],
#  u'929942': [u'gothic'],
#  u'802879': [u'mix'],
#  u'802878': [u'sleepi', u'time'],
#  u'802871': [u'danc'],
#  u'802870': [u'rock', u'world'],
#  u'802873': [u'best'],
#  u'802872': [u'shawn', u'mend'],
#  u'802875': [u'sxsw'],
#  u'802874': [u'europ'],
#  u'802877': [u'new', u'new'],
#  u'802876': [u'inspir'],
#  u'265108': [u'beast'],
#  u'265109': [u'summer', u'2k17'],
#  u'265100': [u'electron'],
#  u'265101': [u'cave'],
#  u'265102': [u'fall', u'2017'],
#  u'265103': [u'nye', u'2015'],
#  u'265104': [u'aa'],
#  u'265105': [u'blue'],
#  u'265106': [u'ballet'],
#  u'265107': [u'feelin'],
#  u'940438': [u'colleg'],
#  u'940439': [u'nerd'],
#  u'914679': [u'unknown'],
#  u'914678': [u'highschool'],
#  u'259476': [u'lovey', u'dovey'],
#  u'914673': [u'unknown'],
#  u'914672': [u'chill'],
#  u'914671': [u'workout'],
#  u'914670': [u'haramb'],
#  u'914677': [u'sad', u'music'],
#  u'940435': [u'music'],
#  u'914675': [u'prom'],
#  u'914674': [u'april', u'17'],
#  u'891440': [u'see'],
#  u'891441': [u'hurt'],
#  u'891442': [u'rob'],
#  u'891443': [u'feel', u'good'],
#  u'891444': [u'new'],
#  u'891445': [u'beach', u'day'],
#  u'891446': [u'get', u'it'],
#  u'891447': [u'joey'],
#  u'891448': [u'wake', u'up', u'happi'],
#  u'891449': [u'leagu'],
#  u'762276': [u'car'],
#  u'259472': [u'jam'],
#  u'233039': [u'game', u'playlist'],
#  u'233038': [u'parti'],
#  u'398080': [u'unknown'],
#  u'233033': [u'mood'],
#  u'233032': [u'hype'],
#  u'233031': [u'rocknrolla'],
#  u'233030': [u'bam', u'bam'],
#  u'233037': [u'drive'],
#  u'233036': [u'cute', u'song'],
#  u'233035': [u'spring', u'2013'],
#  u'233034': [u'love'],
#  u'596921': [u'camp'],
#  u'596920': [u'modern', u'countri'],
#  u'596923': [u'ball'],
#  u'596922': [u'2017', u'playlist'],
#  u'596925': [u'parti'],
#  u'596924': [u'emma'],
#  u'596927': [u'pop'],
#  u'596926': [u'summer'],
#  u'596929': [u'heyo'],
#  u'596928': [u'raini', u'day'],
#  u'16702': [u'strength'],
#  u'845917': [u'countri'],
#  u'845916': [u'oldschool'],
#  u'259479': [u'fresh'],
#  u'259478': [u'2015'],
#  u'157249': [u'easi', u'listen'],
#  u'157248': [u'parti', u'hardi'],
#  u'157247': [u'countri', u'favorit'],
#  u'157246': [u'new'],
#  u'157245': [u'open', u'road'],
#  u'157244': [u'capella'],
#  u'157243': [u'cool'],
#  u'157242': [u'pop', u'punk'],
#  u'157241': [u'old', u'school'],
#  u'157240': [u'chill', u'vibe'],
#  u'109851': [u'angst'],
#  u'109850': [u'unknown'],
#  u'109853': [u'back', u'road'],
#  u'109852': [u'love'],
#  u'109855': [u'1234'],
#  u'109854': [u'countri'],
#  u'109857': [u'80', u'music'],
#  u'169928': [u'wed', u'song'],
#  u'109859': [u'great'],
#  u'109858': [u'alt'],
#  u'169925': [u'music'],
#  u'169924': [u'mexico'],
#  u'169923': [u'raini', u'day'],
#  u'169922': [u'drake'],
#  u'169921': [u'summer'],
#  u'169920': [u'good'],
#  u'38382': [u'workout', u'2'],
#  u'472274': [u'sade'],
#  u'472275': [u'may', u'17'],
#  u'472276': [u'list'],
#  u'472277': [u'foreplay'],
#  u'472270': [u'workout', u'1'],
#  u'472271': [u'summa'],
#  u'472272': [u'nf'],
#  u'562099': [u'run'],
#  u'562096': [u'strength'],
#  u'562097': [u'june', u'17'],
#  u'562094': [u'novemb', u'2013'],
#  u'562095': [u'patrick'],
#  u'472278': [u'aaaaaa'],
#  u'472279': [u'juic'],
#  u'562090': [u'justin', u'bieber'],
#  u'562091': [u'worship'],
#  u'598198': [u'mood'],
#  u'598199': [u'happi', u'tune'],
#  u'979281': [u'step', u'up'],
#  u'345899': [u'gym'],
#  u'345898': [u'christian'],
#  u'345897': [u'yep'],
#  u'345896': [u'fire'],
#  u'345895': [u'guitar'],
#  u'345894': [u'late'],
#  u'345893': [u'new'],
#  u'345892': [u'ti', u'season'],
#  u'345891': [u'song'],
#  u'598195': [u'countri', u'love'],
#  u'616289': [u'august'],
#  u'616288': [u'song'],
#  u'230719': [u'draw'],
#  u'230718': [u'august'],
#  u'755063': [u'countri'],
#  u'755062': [u'rnb'],
#  u'755061': [u'childish'],
#  u'755060': [u'merci'],
#  u'230713': [u'strawberri', u'jam'],
#  u'230712': [u'spotifi', u'unknown', u'chill'],
#  u'230711': [u'summer', u'2017'],
#  u'230710': [u'feb', u'16'],
#  u'230717': [u'christma'],
#  u'230716': [u'doo', u'wop'],
#  u'616287': [u'stagecoach', u'2016'],
#  u'616286': [u'child', u'play'],
#  u'932035': [u'grime'],
#  u'671258': [u'georgia'],
#  u'218092': [u'christma'],
#  u'218093': [u'good', u'stuff'],
#  u'218090': [u'sleepi'],
#  u'218091': [u'worship'],
#  u'218096': [u'shower'],
#  u'218097': [u'christma'],
#  u'218094': [u'disco'],
#  u'218095': [u'chillin'],
#  u'614252': [u'work'],
#  u'218098': [u'listen'],
#  u'218099': [u'rap'],
#  u'795512': [u'rb'],
#  u'888831': [u'alright'],
#  u'981699': [u'salsa'],
#  u'981698': [u'drop', u'beat'],
#  u'981697': [u'relax'],
#  u'981696': [u'20'],
#  u'981695': [u'song'],
#  u'981694': [u'southern'],
#  u'981693': [u'may', u'2017'],
#  u'981692': [u'america'],
#  u'981691': [u'jam'],
#  u'981690': [u'unknown'],
#  u'205397': [u'septemb', u'17'],
#  u'205396': [u'top', u'rock'],
#  u'205395': [u'road', u'trip'],
#  u'205394': [u'mo'],
#  u'205393': [u'kevin', u'gate'],
#  u'205392': [u'feel'],
#  u'205391': [u'oldi'],
#  u'205390': [u'yin', u'yoga'],
#  u'976739': [u'25'],
#  u'205399': [u'hey'],
#  u'205398': [u'old'],
#  u'667797': [u'bruh'],
#  u'667796': [u'anna'],
#  u'667795': [u'tbt'],
#  u'667794': [u'feelin', u'good'],
#  u'667793': [u'car', u'jam'],
#  u'667792': [u'sweet', u'music'],
#  u'667791': [u'gospel'],
#  u'667790': [u'idk'],
#  u'667799': [u'rb'],
#  u'667798': [u'septemb'],
#  u'99860': [u'hu'],
#  u'619958': [u'tb'],
#  u'619959': [u'good', u'song'],
#  u'619954': [u'daddi'],
#  u'619955': [u'slow'],
#  u'619956': [u'jamz'],
#  u'619957': [u'summer', u'2015'],
#  u'619950': [u'tranc'],
#  u'619951': [u'chillin'],
#  u'619952': [u'good', u'tune'],
#  u'619953': [u'gigi'],
#  u'463001': [u'move'],
#  u'726089': [u'boat'],
#  u'742884': [u'uplift'],
#  u'726087': [u'countri'],
#  u'726086': [u'oh', u'happi', u'day'],
#  u'726085': [u'new'],
#  u'726084': [u'pregam', u'hype'],
#  u'726083': [u'strip'],
#  u'726082': [u'fav', u'song'],
#  u'726081': [u'christian', u'rap'],
#  u'726080': [u'psych'],
#  u'820228': [u'countri'],
#  u'820229': [u'slytherin'],
#  u'353264': [u'dump'],
#  u'820220': [u'mi', u'playlist'],
#  u'820221': [u'friday'],
#  u'820222': [u'lizzi'],
#  u'820223': [u'listen', u'to'],
#  u'820224': [u'easi', u'listen'],
#  u'820225': [u'metal'],
#  u'820226': [u'ho'],
#  u'820227': [u'drive', u'mix'],
#  u'170914': [u'singersongwrit'],
#  u'170915': [u'road', u'trippin'],
#  u'170916': [u'bryce'],
#  u'170917': [u'banda'],
#  u'170910': [u'may', u'2016'],
#  u'170911': [u'road', u'trip'],
#  u'170912': [u'birthday'],
#  u'170913': [u'regga'],
#  u'353260': [u'90'],
#  u'170918': [u'ay', u'vamo'],
#  u'170919': [u'sweet', u'sound'],
#  u'38569': [u'memori'],
#  u'38568': [u'octob'],
#  u'281078': [u'heart'],
#  u'281079': [u'summer', u'2015'],
#  u'517913': [u'yeehaw'],
#  u'517912': [u'unknown'],
#  u'517911': [u'new', u'hip', u'hop'],
#  u'517910': [u'eminem'],
#  u'38561': [u'rb'],
#  u'38560': [u'leagu', u'playlist'],
#  u'38563': [u'unknown'],
#  u'38562': [u'music'],
#  u'38565': [u'worship'],
#  u'38564': [u'chill', u'music'],
#  u'38567': [u'jay'],
#  u'38566': [u'90', u'music'],
#  u'320298': [u'portland'],
#  u'320299': [u'januari', u'2016'],
#  u'320290': [u'high', u'school'],
#  u'320291': [u'sap'],
#  u'320292': [u'pop'],
#  u'320293': [u'bump', u'n', u'grind'],
#  u'320294': [u'it', u'lit'],
#  u'320295': [u'old', u'good'],
#  u'320296': [u'cb'],
#  u'320297': [u'soccer', u'playlist'],
#  u'236904': [u'mix'],
#  u'236905': [u'jazz'],
#  u'236906': [u'jam'],
#  u'236907': [u'armi'],
#  u'236900': [u'ayy'],
#  u'236901': [u'old', u'new'],
#  u'236902': [u'2000'],
#  u'236903': [u'tech', u'n9ne'],
#  u'236908': [u'car'],
#  u'236909': [u'jam'],
#  u'246204': [u'basebal'],
#  u'246205': [u'throwback'],
#  u'246206': [u'idk'],
#  u'246207': [u'music'],
#  u'246200': [u'turn', u'up'],
#  u'246201': [u'stuff'],
#  u'246202': [u'road', u'trip'],
#  u'246203': [u'onerepubl', u'unknown', u'nativ'],
#  u'246208': [u'chill'],
#  u'246209': [u'db'],
#  u'175249': [u'warm', u'up'],
#  u'175248': [u'song'],
#  u'175243': [u'daddi'],
#  u'175242': [u'jazzi'],
#  u'175241': [u'highschool'],
#  u'175240': [u'3'],
#  u'175247': [u'70'],
#  u'175246': [u'new'],
#  u'175245': [u'classic'],
#  u'175244': [u'anxieti'],
#  u'123949': [u'random'],
#  u'123948': [u'mix', u'tape'],
#  u'123943': [u'word'],
#  u'123942': [u'ssss'],
#  u'123941': [u'new', u'countri'],
#  u'123940': [u'bbq'],
#  u'123947': [u'love'],
#  u'123946': [u'pop'],
#  u'123945': [u'alt'],
#  u'123944': [u'rb'],
#  u'657615': [u'wed', u'recept'],
#  u'820751': [u'christian', u'rap'],
#  u'820752': [u'regga'],
#  u'820753': [u'stuff'],
#  u'398738': [],
#  u'398739': [u'ck'],
#  u'398734': [u'mix', u'tape'],
#  u'398735': [u'car'],
#  u'575476': [u'worship'],
#  u'398737': [u'walk', u'dream'],
#  u'398730': [u'hype'],
#  u'398731': [u'white', u'music'],
#  u'398732': [u'root'],
#  u'398733': [u'danc', u'parti'],
#  u'83637': [u'hype'],
#  u'83636': [u'chill'],
#  u'83635': [u'studi'],
#  u'83634': [u'overwatch'],
#  u'83633': [u'best', u'music', u'ever'],
#  u'739015': [],
#  u'83631': [u'live'],
#  u'83630': [u'insomnia'],
#  u'323981': [u'motown'],
#  u'323980': [u'vibe'],
#  u'323983': [u'feelin', u'myself'],
#  u'323982': [u'peyton'],
#  u'323985': [u'christma'],
#  u'323984': [u'spring17'],
#  u'83639': [u'unknown'],
#  u'83638': [u'ganja'],
#  u'693710': [u'good', u'stuff'],
#  u'693711': [u'imagin'],
#  u'693712': [u'songsss'],
#  u'916805': [u'music'],
#  u'693714': [u'sad', u'song'],
#  u'693715': [u'rock'],
#  u'693716': [u'spring', u'16'],
#  u'693717': [u'fire'],
#  u'693718': [u'rock'],
#  u'693719': [u'ye', u'pleas'],
#  u'916808': [u'greek'],
#  u'916809': [u'summer2013'],
#  u'803252': [u'rap'],
#  u'803253': [u'banda'],
#  u'803250': [u'mariah'],
#  u'803251': [u'dr'],
#  u'803256': [u'feel'],
#  u'803257': [u'happi'],
#  u'803254': [u'sound'],
#  u'803255': [u'may', u'2016'],
#  u'707833': [u'classic'],
#  u'803258': [u'chillin'],
#  u'803259': [u'car'],
#  u'707832': [u'banger'],
#  u'785552': [u'throwback'],
#  u'785553': [u'loung', u'music'],
#  u'785550': [u'pump'],
#  u'785551': [u'christmastim'],
#  u'785556': [u'espaol'],
#  u'785557': [u'work', u'1'],
#  u'785554': [u'workout'],
#  u'785555': [u'hi'],
#  u'785558': [u'octob', u'16'],
#  u'785559': [u'slap'],
#  u'591289': [u'drive'],
#  u'591288': [u'preceremoni'],
#  u'591285': [u'weightless'],
#  u'591284': [u'chill'],
#  u'591287': [u'trap', u'music'],
#  u'591286': [u'june', u'2016'],
#  u'591281': [u'3'],
#  u'591280': [u'fish'],
#  u'591283': [u'classic'],
#  u'591282': [u'throw', u'back'],
#  u'214373': [u'old', u'countri'],
#  u'214372': [u'too', u'much', u'sauc'],
#  u'214371': [u'wordless'],
#  u'451992': [u'classic', u'piano'],
#  u'451993': [u'lit'],
#  u'451990': [u'kati'],
#  u'451991': [u'plane'],
#  u'451996': [u'rb'],
#  u'451997': [u'parti'],
#  u'451994': [u'2016'],
#  u'451995': [u'jw'],
#  u'214377': [u'hypebeast'],
#  u'451998': [u'pesado'],
#  u'451999': [u'studi'],
#  u'214376': [u'rap'],
#  u'651839': [u'unknown'],
#  u'214374': [u'car'],
#  u'207098': [u'golden', u'oldi'],
#  u'207099': [u'spring', u'2015'],
#  u'213185': [u'regga'],
#  u'213184': [u'studi'],
#  u'213187': [u'mel'],
#  u'213186': [u'spring', u'break', u'2016'],
#  u'213181': [u'playlist'],
#  u'213180': [u'halloween'],
#  u'213183': [u'unknown'],
#  u'213182': [u'oldi', u'goodi'],
#  u'835200': [u'water'],
#  u'835201': [u'hope'],
#  u'835202': [u'brandon'],
#  u'835203': [u'hm'],
#  u'213189': [u'hello'],
#  u'213188': [u'car', u'ride'],
#  u'835206': [u'old', u'school'],
#  u'835207': [u'fall', u'2013'],
#  u'296878': [u'vibe'],
#  u'154848': [u'random'],
#  u'154849': [u'vin'],
#  u'120629': [u'brasil'],
#  u'120628': [u'rock'],
#  u'999499': [u'storm'],
#  u'120623': [u'instrument'],
#  u'120622': [u'feel', u'good', u'music'],
#  u'120621': [u'90'],
#  u'154843': [u'jamz'],
#  u'120627': [u'parti'],
#  u'120626': [u'cover'],
#  u'120625': [u'pop', u'song'],
#  u'120624': [u'game', u'day'],
#  u'926663': [u'grow', u'up'],
#  u'158282': [u'oldi'],
#  u'158283': [u'hip', u'hop'],
#  u'158280': [u'august'],
#  u'158281': [u'90'],
#  u'158286': [u'sad'],
#  u'158287': [u'japanes'],
#  u'158284': [u'everyth'],
#  u'158285': [u'isra', u'music'],
#  u'158288': [u'oldi'],
#  u'158289': [u'orang'],
#  u'586497': [u'espaol'],
#  u'488789': [u'pop'],
#  u'488788': [u'sleep'],
#  u'84262': [u'countryyi'],
#  u'774409': [u'pump', u'up'],
#  u'488785': [u'burn'],
#  u'25500': [u'devin'],
#  u'488784': [u'worship'],
#  u'539801': [u'christma'],
#  u'539800': [u'dirti'],
#  u'539803': [u'kpop'],
#  u'539802': [u'duh'],
#  u'539805': [u'goodvib'],
#  u'539804': [u'justin'],
#  u'539807': [u'sweet'],
#  u'539806': [u'explor'],
#  u'539809': [u'high', u'school'],
#  u'539808': [u'spanish', u'trap'],
#  u'2231': [u'rap'],
#  u'192054': [u'countri'],
#  u'320647': [u'oldi'],
#  u'807382': [u'jamz'],
#  u'2233': [u'new', u'list'],
#  u'2232': [u'fun'],
#  u'250818': [u'hurrican'],
#  u'250819': [u'rap'],
#  u'250816': [u'teen'],
#  u'250817': [u'r', u'p'],
#  u'250814': [u'work', u'music'],
#  u'250815': [u'christma'],
#  u'250812': [u'fff'],
#  u'250813': [u'neon'],
#  u'250810': [u'disney', u'jam'],
#  u'250811': [u'halloween', u'parti'],
#  u'2237': [u'123'],
#  u'260318': [u'awesom'],
#  u'260319': [u'showerrr'],
#  u'260316': [u'work', u'progress'],
#  u'260317': [u'dad', u'playlist'],
#  u'260314': [u'disney'],
#  u'260315': [u'chill'],
#  u'260312': [u'wed', u'unknown', u'danc'],
#  u'260313': [u'ska'],
#  u'260310': [u'flower'],
#  u'260311': [u'franai'],
#  u'300043': [u'boat'],
#  u'300042': [u'chillen'],
#  u'300041': [u'je'],
#  u'300040': [u'rb'],
#  u'300047': [u'vroom', u'vroom'],
#  u'300046': [u'otf'],
#  u'300045': [u'red', u'dirt'],
#  u'300044': [u'throwback'],
#  u'925857': [u'50'],
#  u'875708': [u'indi', u'rock'],
#  u'300049': [u'goal'],
#  u'300048': [u'groov'],
#  u'925853': [u'jonni'],
#  u'925852': [u'oldi'],
#  u'925851': [u'crunk'],
#  u'925850': [u'power', u'ballad'],
#  u'806372': [u'random', u'song'],
#  u'806373': [u'random'],
#  u'806370': [u'adoracin'],
#  u'806371': [u'happi', u'playlist'],
#  u'806376': [u'brunch'],
#  u'806377': [u'tango'],
#  u'806374': [u'raini', u'day'],
#  u'806375': [u'unknown'],
#  u'417676': [u'anthoni'],
#  u'579728': [u'rumba'],
#  u'806378': [u'beach', u'playlist'],
#  u'806379': [u'chill', u'danc'],
#  u'51921': [u'januari', u'2016'],
#  u'162575': [u'festiv'],
#  u'162574': [u'bbq'],
#  u'162577': [u'guardian', u'galaxi'],
#  u'162576': [u'run'],
#  u'162571': [],
#  u'162570': [u'jenn'],
#  u'162573': [u'lalala'],
#  u'162572': [u'underground'],
#  u'469999': [u'happi', u'unknown'],
#  u'469998': [u'anger'],
#  u'256476': [u'king'],
#  u'842490': [u'exercis'],
#  u'162579': [u'epic'],
#  u'162578': [u'banda'],
#  u'700696': [u'parti'],
#  u'510260': [u'amelia'],
#  u'510261': [u'worship'],
#  u'510262': [u'grad', u'parti'],
#  u'510263': [u'dank'],
#  u'510264': [u'august'],
#  u'510265': [u'jam', u'band'],
#  u'510266': [u'throwback'],
#  u'510267': [u'vibin'],
#  u'510268': [u'danc'],
#  u'510269': [u'christma'],
#  u'579720': [u'g', u'funk'],
#  u'579721': [u'summer', u'2015'],
#  u'930910': [u'wo'],
#  u'930911': [u'ador'],
#  u'190789': [u'workout'],
#  u'190788': [u'old', u'school'],
#  u'895769': [u'slow'],
#  u'895768': [u'gym'],
#  u'930916': [u'laura', u'unknown'],
#  u'930917': [u'marta'],
#  u'190783': [u'english'],
#  u'190782': [u'work'],
#  u'190781': [u'christma'],
#  u'190780': [u'danc', u'music'],
#  u'190787': [u'new', u'play'],
#  u'190786': [u'80'],
#  u'190785': [u'wed', u'recept'],
#  u'190784': [u'dubstep'],
#  u'295068': [u'hookah'],
#  u'295069': [u'fade'],
#  u'295064': [u'happi'],
#  u'295065': [u'wb'],
#  u'295066': [u'oldi', u'mix'],
#  u'295067': [u'stagecoach', u'2016'],
#  u'295060': [u'fall', u'15'],
#  u'295061': [u'classic', u'rock'],
#  u'295062': [u'philli'],
#  u'295063': [u'christma'],
#  u'152275': [u'7th', u'grade'],
#  u'152274': [u'time', u'low'],
#  u'152277': [u'irish'],
#  u'152276': [u'teen', u'angst'],
#  u'152271': [u'dom'],
#  u'152270': [u'unknown'],
#  u'152273': [u'latin', u'mix'],
#  u'152272': [u'novemb'],
#  u'152279': [u'hype'],
#  u'152278': [u'willi', u'nelson'],
#  u'898069': [u'feel'],
#  u'898068': [u'lit'],
#  u'417400': [u'baila'],
#  u'898061': [u'love', u'song'],
#  u'898060': [u'tb'],
#  u'898063': [u'tranc'],
#  u'898062': [u'good', u'good'],
#  u'898065': [u'summer'],
#  u'898064': [u'phone'],
#  u'898067': [u'rb'],
#  u'898066': [u'repeat'],
#  u'398699': [u'throwback'],
#  u'575558': [u'weird'],
#  u'288181': [u'peac', u'piano'],
#  u'288180': [u'oldi'],
#  u'288183': [u'bowi'],
#  u'288182': [u'run'],
#  u'288185': [u'cr'],
#  u'288184': [u'bae'],
#  u'288187': [u'jammin'],
#  u'288186': [u'hsm'],
#  u'288189': [],
#  u'288188': [u'mz'],
#  u'982261': [u'gari'],
#  u'982260': [u'happi', u'unknown'],
#  u'982267': [u'rock'],
#  u'982266': [u'ya'],
#  u'982265': [u'travel'],
#  u'982264': [u'rock', u'espaol'],
#  u'870118': [u'love'],
#  u'398694': [u'band', u'music'],
#  u'398693': [u'work'],
#  u'120197': [u'workout'],
#  u'398692': [u'20'],
#  ...}

# %%
Task = str(1)

# %%
if Task == '1':
    bar = 1
elif Task == '2':
    bar = 5
elif Task == '5':
    bar = 10
elif Task == '6':
    bar = 25
elif Task == '7':
    bar = 25
elif Task == '9':
    bar = 100

# %% [markdown]
# ## For different Task (change from here)

# %%
Xing_Raw = json.load(open('../MODEL_5_Counter_Artist_Album/Pure_Xing/Pure_Xing_T' + Task + '.json'))
Xing = {}
for pl in Xing_Raw:
    Xing[pl] = []
    for t in Xing_Raw[pl]:
        Xing[pl].append(track_index_reversed[t])

# %%
QQ = json.load(open('../MODEL_5_Counter_Artist_Album/Pure_QQ/Pure_QQ_T' + Task + '.json'))

# %% [markdown]
# ## Combine Method 1 (Used in current submission)

# %%
def combine_method_1(QQ_dict, Xing_dict):
    R_combined = {}
    for pl in Xing_dict:
        if len(Xing_dict[pl]) == 500:
            R_combined[pl] = Xing_dict[pl][:]
        else:
            rest = 500 - len(Xing_dict[pl])
            R_combined[pl] = Xing_dict[pl][:]
            for t in QQ_dict[pl]:
                if t not in R_combined[pl]:
                    R_combined[pl].append(t)
                    
                if len(R_combined[pl]) == 500:
                    break
    return R_combined

# %%
Combined_R_method_1 = combine_method_1(QQ, Xing)

# %%
R_precision_1 = {}
NDCG_1 = {}
Clicks_1 = {}

for pl in Xing:

    R_precision_1[pl] = r_precision(GT[pl][bar:], Combined_R_method_1[pl])
    NDCG_1[pl] = ndcg(GT[pl][bar:], Combined_R_method_1[pl])
    Clicks_1[pl] = clicks(GT[pl][bar:], Combined_R_method_1[pl])
    
print sum(R_precision_1.values()) / len(R_precision_1)
print sum(NDCG_1.values()) / len(NDCG_1)
print sum(Clicks_1.values()) / len(Clicks_1)
# Out:
# 0.131532696672
# 0.2652868259054635
# 3.735

# %% [markdown]
# ## Combine Method 2

# %%
def rank(new, current, sort_base):
    layer = list(set(new) - set(current))
    layer_index = {}
    for elem in layer:
        layer_index[elem] = sort_base[elem]
        
    layer_sorted = sorted(layer_index.items(), key=operator.itemgetter(1))
    layer_final = [i[0] for i in layer_sorted]
    return current + layer_final

def combine_method_2_sub_1(QQ, Xing, GT_len):
    QQ_index = {}
    for elem in QQ:
        QQ_index[elem] = len(QQ_index)
    
    Xing_index = {}
    for elem in Xing:
        Xing_index[elem] = len(Xing_index)
        
        
    Ax = set(Xing[:GT_len])
    Bx = set(Xing[GT_len:])
        
    Aq = set(QQ[:GT_len])
    Bq = set(QQ[GT_len:])
    
    # Layer 1
    up_to_layer1 = rank(list(Ax & Aq), [], Xing_index)
    
    # Layer 2 part 1
    up_to_layer2_1 = rank(list(Ax & Bq), up_to_layer1, Xing_index)

    # Layer 2 part 2
    up_to_layer2_2 = rank(list(Bx & Aq), up_to_layer2_1, Xing_index)
    
    # Layer 3 part 1
    up_to_layer3_1 = rank(list(Ax), up_to_layer2_2, Xing_index)
    
    # Layer 3 part 2
    up_to_layer3_2 = rank(list(Aq), up_to_layer3_1, QQ_index)
    
    # Layer 3 part 3
    up_to_layer3_3 = rank(list(Bx & Bq), up_to_layer3_2, Xing_index)
    
    # Layer 4 part 1
    up_to_layer4_1 = rank(list(Bx), up_to_layer3_3, Xing_index)
    
    # Layer 4 part 2
    up_to_layer4_2 = rank(list(Bq), up_to_layer4_1, QQ_index)
    
    return up_to_layer4_2[:500]

def combine_method_2_sub_2(QQ, Xing, GT_len):
    QQ_index = {}
    for elem in QQ:
        QQ_index[elem] = len(QQ_index)
    
    Xing_index = {}
    for elem in Xing:
        Xing_index[elem] = len(Xing_index)
        
        
    Ax = set(Xing[:GT_len])
    Bx = set(Xing[GT_len:])
        
    Aq = set(QQ[:GT_len])
    Bq = set(QQ[GT_len:])
    
    # Layer 1
    up_to_layer1 = rank(list(Ax & Aq), [], Xing_index)
    
    # Layer 2 part 1
    up_to_layer2_1 = rank(list(Ax & Bq), up_to_layer1, Xing_index)


    # Layer 2 part 2
    up_to_layer2_2 = rank(list(Ax), up_to_layer2_1, Xing_index)
    
    # Layer 3 part 1
    up_to_layer3_1 = rank(list(Bx & Aq), up_to_layer2_2, Xing_index)
    
    # Layer 3 part 2
    up_to_layer3_2 = rank(list(Aq), up_to_layer3_1, QQ_index)
    
    # Layer 3 part 3
    up_to_layer3_3 = rank(list(Bx & Bq), up_to_layer3_2, Xing_index)
    
    # Layer 4 part 1
    up_to_layer4_1 = rank(list(Bx), up_to_layer3_3, Xing_index)
    
    # Layer 4 part 2
    up_to_layer4_2 = rank(list(Bq), up_to_layer4_1, QQ_index)
    
    return up_to_layer4_2[:500]

def combine_method_2_sub_3(QQ, Xing, GT_len):
    QQ_index = {}
    for elem in QQ:
        QQ_index[elem] = len(QQ_index)
    
    Xing_index = {}
    for elem in Xing:
        Xing_index[elem] = len(Xing_index)
        
        
    Ax = set(Xing[:GT_len])
    Bx = set(Xing[GT_len:])
        
    Aq = set(QQ[:GT_len])
    Bq = set(QQ[GT_len:])
    
    # Layer 1
    up_to_layer1 = rank(list(Ax & Aq), [], Xing_index)
    

    # Layer 2 part 2
    up_to_layer2_1 = rank(list(Bx & Aq), up_to_layer1, Xing_index)
    
    # Layer 2 part 1
    up_to_layer2_2 = rank(list(Ax & Bq), up_to_layer2_1, Xing_index)
    
    # Layer 3 part 1
    up_to_layer3_1 = rank(list(Ax), up_to_layer2_2, Xing_index)
    
    # Layer 3 part 2
    up_to_layer3_2 = rank(list(Aq), up_to_layer3_1, QQ_index)
    
    # Layer 3 part 3
    up_to_layer3_3 = rank(list(Bx & Bq), up_to_layer3_2, Xing_index)
    
    # Layer 4 part 1
    up_to_layer4_1 = rank(list(Bx), up_to_layer3_3, Xing_index)
    
    # Layer 4 part 2
    up_to_layer4_2 = rank(list(Bq), up_to_layer4_1, QQ_index)
    
    return up_to_layer4_2[:500]

def combine_method_2_sub_4(QQ, Xing, GT_len):
    QQ_index = {}
    for elem in QQ:
        QQ_index[elem] = len(QQ_index) * 1.5
    
    Xing_index = {}
    for elem in Xing:
        Xing_index[elem] = len(Xing_index) * 1.0 
        
    final_index = {}
    for elem in list(set(Xing_index.keys()) | set(QQ_index.keys())):
        if elem in Xing and elem not in QQ:
            final_index[elem] = Xing_index[elem]
        elif elem in QQ and elem not in Xing:
            final_index[elem] = QQ_index[elem]
        else:
            final_index[elem] = Xing_index[elem] + QQ_index[elem]
        
        
    Ax = set(Xing[:GT_len])
    Bx = set(Xing[GT_len:])
        
    Aq = set(QQ[:GT_len])
    Bq = set(QQ[GT_len:])
    
    # Layer 1
    up_to_layer1 = rank(list(Ax & Aq), [], final_index)
    
    # Layer 2 part 1
    up_to_layer2_1 = rank(list(Ax & Bq), up_to_layer1, final_index)

    # Layer 2 part 2
    up_to_layer2_2 = rank(list(Bx & Aq), up_to_layer2_1, final_index)
    
    # Layer 3 part 1
    up_to_layer3_1 = rank(list(Ax), up_to_layer2_2, final_index)
    
    # Layer 3 part 2
    up_to_layer3_2 = rank(list(Aq), up_to_layer3_1, final_index)
    
    # Layer 3 part 3
    up_to_layer3_3 = rank(list(Bx & Bq), up_to_layer3_2, final_index)
    
    # Layer 4 part 1
    up_to_layer4_1 = rank(list(Bx), up_to_layer3_3, final_index)
    
    # Layer 4 part 2
    up_to_layer4_2 = rank(list(Bq), up_to_layer4_1, final_index)
    
    return up_to_layer4_2[:500]

def combine_method_2(QQ_dict, Xing_dict):
    global GT
    R_combined = {}
    for pl in Xing_dict:
        R_combined[pl] = combine_method_2_sub_4(QQ_dict[pl], Xing_dict[pl],len(GT[pl]) - bar)
    return R_combined

# %%
Combined_R_method_2 = combine_method_2(QQ, Xing)

# %%
R_precision_2 = {}
NDCG_2 = {}
Clicks_2 = {}

for pl in Xing:
    R_precision_2[pl] = r_precision(GT[pl][bar:], Combined_R_method_2[pl])
    NDCG_2[pl] = ndcg(GT[pl][bar:], Combined_R_method_2[pl])
    Clicks_2[pl] = clicks(GT[pl][bar:], Combined_R_method_2[pl])

print sum(R_precision_2.values()) / len(R_precision_2)
print sum(NDCG_2.values()) / len(NDCG_2)
print sum(Clicks_2.values()) / len(Clicks_2)
# Out:
# 0.127524093904
# 0.2541168030277581
# 3.725

# %% [markdown]
# ## Combine Name

# %%
for pl in Combined_R_method_2:
    if 'disney' in pl_title[pl]:
        print pl, pl_title[pl], R_precision_2[pl], NDCG_2[pl], Clicks_2[pl]
# Out:
# 871403 [u'disney'] 0.494736842105 0.81369119454738 0.0
# 756385 [u'disney', u'song'] 0.369565217391 0.49557859934636966 0.0
# 269560 [u'disney', u'playlist'] 0.36036036036 0.529287003183974 0.0
# 21475 [u'disney', u'playlist'] 0.213836477987 0.3816425019505249 1.0
# 757005 [u'disney'] 0.30612244898 0.6555367411032229 0.0
# 989172 [u'disney'] 0.369565217391 0.749178565739931 0.0
# 868495 [u'disney'] 0.448598130841 0.6784616423617634 0.0
# 292980 [u'disney'] 0.381944444444 0.45175087981072737 0.0

# %%
for pl in Combined_R_method_2:
    if 'christma' in pl_title[pl]:
        print pl, pl_title[pl], R_precision_2[pl], NDCG_2[pl], Clicks_2[pl]
# Out:
# 486203 [u'christma'] 0.568181818182 0.8568847809489814 0.0
# 178107 [u'christma'] 0.125 0.33414610581524795 0.0
# 37123 [u'christma', u'unknown'] 0.275862068966 0.5576577721721971 0.0
# 823508 [u'christma'] 0.224719101124 0.2962329949179522 0.0
# 737570 [u'christma'] 0.5 0.7558089704874346 0.0
# 716782 [u'christma'] 0.636363636364 0.8114838483951254 0.0
# 932794 [u'christma', u'af'] 0.4 0.6333505396472532 0.0
# 235877 [u'christma'] 0.233333333333 0.602188169395064 0.0
# 994666 [u'christma'] 0.215053763441 0.3939442833166407 0.0

# %%
selected_title = json.load(open('Selected_Title_Top_1000.json'))

# %%
R_disney = {}
for pl in Combined_R_method_2:
    if 'christma' in pl_title[pl]:
        R_disney[pl] = []
        for track in selected_title['christma']:
            if track not in GT[pl]:
                R_disney[pl].append(track)
            if len(R_disney[pl]) == 500:
                break

# %%
for pl in R_disney:
    print pl, len(R_disney[pl]), r_precision(GT[pl][bar:], R_disney[pl]), ndcg(GT[pl][bar:], R_disney[pl]), clicks(GT[pl][bar:], R_disney[pl])
# Out:
# 994666 500 0.0 0.0 51
# 932794 500 0.0 0.0 51
# 737570 500 0.0 0.0 51
# 235877 500 0.0 0.0 51
# 178107 500 0.0 0.0 51
# 486203 500 0.0 0.0 51
# 823508 500 0.0 0.0 51
# 716782 500 0.0 0.0 51
# 37123 500 0.0 0.0 51

# %%
R_precision_disney = {}
NDCG_disney = {}
Clicks_disney = {}

for pl in R_disney:
    R_precision_disney[pl] = r_precision(GT[pl][bar:], R_disney[pl])
    NDCG_disney[pl] = ndcg(GT[pl][bar:], R_disney[pl])
    Clicks_disney[pl] = clicks(GT[pl][bar:], R_disney[pl])

print sum(R_precision_disney.values()) / len(R_precision_disney)
print sum(NDCG_disney.values()) / len(NDCG_disney)
print sum(Clicks_disney.values()) / len(Clicks_disney)
# Out:
# 0.0
# 0.0
# 51

# %%
R_precision_disney
# Out:
# {u'206139': 0.0,
#  u'491331': 0.0,
#  u'565500': 0.0,
#  u'591221': 0.0,
#  u'762912': 0.0,
#  u'766694': 0.0,
#  u'978487': 0.0,
#  u'996378': 0.0}

# %%
GT['688612'][bar:]
# Out:
# [u'3ZRiCa1ROwlxKftO79ghJ1',
#  u'14sDzaqoSmpyqXkyaDDtyi',
#  u'59Sww77uD7VwyN0hlMKBWs',
#  u'5owH90gSdbZK9Iot4bCrjQ',
#  u'3pKRp4NX0YDl1bRANjJLSU',
#  u'2PhptzkiJ8kVQsO7tpRWLS',
#  u'3KhPDba7BR2uDM7tVep0dg',
#  u'1I7MQWuGQPxuEplPwEhj8i',
#  u'66XM8JXKr9A39wBMqIbytS',
#  u'3hZJ36jOs508nezkO740EM',
#  u'0IvBHyirLy7fLickwsqyA4',
#  u'6KpgqZwN6zen3qtOaz6rPl',
#  u'1p5dAU2s6kekj05gRVImTH',
#  u'2TPAS9lv9qceJT7o8oSNep',
#  u'3XBQciUm8idlYY3XoxlTiC',
#  u'7BjEZBsds3n6tN9KTEZpK4',
#  u'1xSEPN2WYdq8xrAXpCG9CO',
#  u'1ytmdDK5IqzTGhmEc4gHIt',
#  u'6Y5hGmficfyzKfSQtRpOch',
#  u'23LqDcaYel42gfSJ05tsC0',
#  u'4izlxzOjLPRzWy6Co5x0N0',
#  u'1hVanDiOYB9WLcRDbyo9xo',
#  u'00FWuEBvnitgpbMSk0XIoN',
#  u'2W8R0DqYzyHMe6DKYRKjSP',
#  u'6ZGoXOzTtHZCfKLUdypJp9',
#  u'2m7EWjTKCfNqrAdL1FSpd4',
#  u'504Ip38tLo9RbbSPIuThPB',
#  u'1TS55Vgmn2rwNvaNFP4ZTj',
#  u'6zkf9XiGqi7PXPMLrkyHWR',
#  u'52xOIchaCeR8r1S4iyRvY1',
#  u'3H0qlRXLI0R0B6HRZhoJTv',
#  u'5sLA16kNCBbGkx08ui3Z23',
#  u'1pjsyVQfEsVT3GBo6HB8YX',
#  u'1ayBtR0Zu8vtNLjRs0sl0U',
#  u'0pWl3k2PVLQ58aBCnxPh5e',
#  u'1z5UFKy8gJpVDf09lCtPOr',
#  u'78g59al24LFeC5UCvrGZKb',
#  u'2CBm77LCNuHLiEhnmiZnHm',
#  u'4D4Fhfexqg5hFyH6Zjha1r',
#  u'3cVGedYgQGq42UbEDXxLVr',
#  u'5YjfusMHRacdLqBJfXGAVu']

# %%
R_disney['688612']
# Out:
# [u'6klpXs2uAjagnZMFkt4qkl',
#  u'03xWMkKEbeO4SnylA53ipj',
#  u'3IPnBzGRMg6BfViFxxa0Gq',
#  u'3E99KpWAcYEnj64e86y6u9',
#  u'2stkLJ0JNcXkIRDNF3ld6c',
#  u'6hhVS4jyOPioRJaY1zVRHj',
#  u'0TCt7OFRdD8PQ6vTRQxNgQ',
#  u'2dlxN435ZY9ruxGYND2Hq0',
#  u'0loKEMa9DP6mLibdFMe6Uv',
#  u'7GmiJVBAzWNikX5VkNQg85',
#  u'15p4zvWigjysxyDwabL8Gw',
#  u'1lOSxJNCLvWm2bYaTcTSmK',
#  u'3uVkugZz6yCTw5Z8sDI19F',
#  u'5mXBaDm21IbxvWSl1AHCpq',
#  u'65V4OsgLqztVY0mlOx5HEh',
#  u'6LBfozDVA7crIeuaPAVVlE',
#  u'7KdrsGJ5ERh7JOjnbieCSd',
#  u'3uZIfWx5ridUBQevmgHDUt',
#  u'4qKDjmz094Bu2wMepNuwVN',
#  u'31cQvIaB5epWhLeY8TGEnK',
#  u'75Cb4PvGJgN3netemAGU4a',
#  u'2hKYhft1VITPST4iiAHLGC',
#  u'6xfazmMoilCmVh44gQ376g',
#  u'7sYaJXMEvq3q91jJNm8I7I',
#  u'1m1lMBFsQmFHNEceXYHL0K',
#  u'0II9l1sI3Mo9XKaszKfizl',
#  u'6V58LMEeGuOfLkCRJKnItb',
#  u'7xf3S6Bv8hDqOtevZou602',
#  u'0UzrSV4nUqkYUUTyhjRf7Z',
#  u'1OzSfjFW08DTD51XoNnog7',
#  u'1LBcs9JY4DedNGwQ61Jztv',
#  u'2Rddbad3XaTds95LY8iidH',
#  u'699vChUaGvvlGuwpItAIVY',
#  u'1fQ2pN9MLxxi399nlHEth7',
#  u'4T9Jpft8jvZAP57aE3VdCt',
#  u'50ssiEHx556vul2XyUbxwU',
#  u'1xQBlIIAZZtekq4pyCp2Lw',
#  u'3qrH2YFnbEiQeUe4wzgOuP',
#  u'0BXmWSeBL9zIazKcbvr2pb',
#  u'3G9ZnSjGYyHx7e221v0qse',
#  u'7G061Oqw7NXFr1NDTpXoI4',
#  u'4vePE79zJShD1QIedYcEgn',
#  u'75VVIB2x1h6BfxD2PqOO57',
#  u'39cgpnPwQ4mfmgTBY1FojG',
#  u'5c1sfI6wIQEsSUw0xrkFdl',
#  u'0QvSSoVdLVSLykpfHTrRHe',
#  u'3AWSwChgStOColFkXbwRnP',
#  u'1SLikaDhWhhhnLJC58bkFI',
#  u'5yyqx4brn6Bm9U1Rj9ENnz',
#  u'7fjmYUeonVOEyr0lYOKvMy',
#  u'6SuebnXnUXBtgtqH871UtF',
#  u'1QkBx7D64jHSalJEQLanwT',
#  u'5NuSl9oJPs7vRoVJi4Se8O',
#  u'5KlCWDbatUCBhvN7ZwyeEF',
#  u'4EnwhEyuVrC1CgvSur5YL4',
#  u'7wjiMdiSgsL9Vkrwb10Num',
#  u'5PPqJ0ji9PYtgLGMMHIi60',
#  u'1uHt85NYsb2JJ05FkAK6as',
#  u'1cPfKp9ThNZ1fez9itmUMN',
#  u'1OwcR9OYz2vuUttTQSOVZN',
#  u'63y2aL2dT6zzw8FOSLaNrp',
#  u'3yPiLKV0BT3FQJD97iacxz',
#  u'6jyXQ8HGI7ikECGA0670uo',
#  u'1v7HQKegIjcBAsAsHjnXZU',
#  u'1KT0xdIjm7t053xByACrrg',
#  u'3KtzpxgZZzTPgNfkObCndB',
#  u'6TRp2628QKH3kY6KrCnjqp',
#  u'2tkIIkF3CPqsmYhsncNEGN',
#  u'6NqfslFfCCOyBQ0Xw8kN8E',
#  u'1ES5V0REvBHhwOFfjEwFYN',
#  u'6YXG34IWbilypPwjBTOrUC',
#  u'1LJtyvOmNOyp0DRpq9of29',
#  u'2XQ1tVtmHNKBOxaCbjYxdn',
#  u'6JGzFddgSUopuksGEZymhn',
#  u'6p6TjiJHc1kJQt5dXzkdrs',
#  u'1GBknQ67DCfKTPms1dw9EW',
#  u'3lP9eoNsz04dMCfPIG0PpK',
#  u'0enYe3J97eUBaxSbZvYNsQ',
#  u'07HPV6hzecJmMJwsIX8YVU',
#  u'3Yn97I3qIj7Px0Bi4rkD2q',
#  u'3Gf3Jsm0k6IPUkogQfKi7S',
#  u'0HscBDeP30qAUEJoZzxNrj',
#  u'5ouuPi1o6eOVSgHn2exemw',
#  u'4jyru1nUrepszk5VMBgsSn',
#  u'2P8QqrZ42YNP8Ao5uRMLO0',
#  u'0zNbaDx3xYJX0143nlrV2i',
#  u'5xmaFH9oMYg8SMMTndypEh',
#  u'1nrXPF5szKZhHr0iANiPcS',
#  u'1ZlwVYK7Qufssn2Ca70u8S',
#  u'5Jwu3ATeTtXbb2pkk6GETD',
#  u'2oj1WfUGiBa8eCyMx5D3I5',
#  u'3RSIUYQxsC6lAE76ctBVku',
#  u'77JhqIuQjqzVmkRTUcm9ji',
#  u'74tQaH4CxM5Rs9BzerEbHr',
#  u'4k9EAtZdZrzPlBUsFncXCZ',
#  u'0IzIW2MSFdllQ7zFLbv1uS',
#  u'7LADJ1Oaf63HsUVFLHHLXZ',
#  u'3eR3lWuvQqOzhTn91nbRCa',
#  u'6YoYLN155MLavQcl3bHmvY',
#  u'400abutrj9yS5YBkd3fE6P',
#  u'3SMxd9vNy41n9Xk4UFw36S',
#  u'42fB9njeMkO1jtrMyQI5cp',
#  u'4WQJPsbGOdqe24mUVHa8xb',
#  u'0UwQOcaLUIenpbQX3RpBfK',
#  u'52G36DyYUiskqVkp9y2aOJ',
#  u'3RuXekS5criwismaaj87iF',
#  u'0lik84UL16pPOevmhQxMYu',
#  u'5EBd8sbeMSyIotWaMnR7s4',
#  u'34pO61aBEB7zveNrKGMh2F',
#  u'5WKxcFnCO244tMnVElhFuk',
#  u'6iPy2jaqzxXa8SpHQkiDCZ',
#  u'6q2r0n2ph4w2p7fLbh5TKK',
#  u'1qH6q58Taljm2MQf6eM0jY',
#  u'6xguT5OygfmfFx2fyoTHQr',
#  u'5sTC1imYc0QzNe3i5snLy7',
#  u'1haQRuZnoggW6U6l5jFIj9',
#  u'0FVduJ39BK7T80wq617H0R',
#  u'20QRXRV7wUFOIgBQCGnUy3',
#  u'3ILyFvcFWtfw2ysOBQMXI5',
#  u'1EwRMgWXS9U8Oet39tlYwY',
#  u'4biuE0gvdD3GpAryIdgVx8',
#  u'7tHKjzBYfMZvprnfyHcOK0',
#  u'1TfAhjzRBWzYZ8IdUV3igl',
#  u'0Qgc2XtzLSbLUeBFDK8X1R',
#  u'4T0GXIWcEIjx7d3KJLLYcR',
#  u'2ppkGKabWsSgNV4fvOldQb',
#  u'5e0O7MjhNHq9G67qDFM8nR',
#  u'4IkWzcb7Zaarlz1lmiKNPE',
#  u'4o6iTWnd0uhuUIRxdWvzP5',
#  u'33GqT5sh9PQq8mnTPWUkco',
#  u'5SWfocxhAkjf3eg4lrv8vZ',
#  u'1R0U7815KtdkiBvWvonfx0',
#  u'7yMnml7zdYl5LlDFZPm5Hd',
#  u'1t055EdeL1r5DfORFy0UXX',
#  u'4SJyy14LvDx7beGTimHp9I',
#  u'6Z0F3Mqj7tq1CBZo5qMlUg',
#  u'5ifL52BDfPFd8zLMA1DOiI',
#  u'3fazam52RUALaUhR6cDadU',
#  u'5ZSaOkmESSzkZRym4ldglJ',
#  u'3XFkhxO5jo2hBOWNzIQ9UB',
#  u'1uT4Haj9BYmbjxvoF2omRc',
#  u'0rzqBHKWkrZZ7R0e2y3abc',
#  u'3LrhBpvdIs7cmwNAtKNk3I',
#  u'5x5JM1BSB6vollcIzDocqT',
#  u'49oQf4PT5ONHU1qHvzfP1g',
#  u'5VwhcviUaJR535GIi1OkjV',
#  u'6a211WVTt0gpRJ3CpRnJV1',
#  u'06IWtDiU8D6DK8vSU072pa',
#  u'5U4wYRHrCRxRP6iQfM824C',
#  u'1ZP0sKDoVM1NCFB65Esfm6',
#  u'1fQ8klMjoSHED4xUSFIkcT',
#  u'2E1V6nbjINpLpiMaWMSYZ4',
#  u'0sXJUHfwsocaJaLM5osoWX',
#  u'3sSpgPbDF16wncH7Zw4kqh',
#  u'2kIq7Oq6YNfdUuTrmPC4w1',
#  u'3a2sDAL3KUtYNuA8ibAJkN',
#  u'0oa7hUynHu9czqX8ZjP2LW',
#  u'4XOkjFJ0qXZr61Lv116ybV',
#  u'6zMa6pq3Te0F9YrEocvgpW',
#  u'7smCjIc7MoUM4ay55LQrdu',
#  u'46jiWFAJktjatRvHxEWh98',
#  u'1g1Jor1zrllXn2ogj8KGAH',
#  u'3waY7uu8cniaQw5Auf0MOp',
#  u'3jR1HXX7vhjlrLrdhLr3NJ',
#  u'5m4RHs0THdfyn579MONxcV',
#  u'6N6mcIhmjN58QhUuMq47m1',
#  u'7CtiVQKP9pkr9i7p6wk4gl',
#  u'3qr68QUa50h7jMELcrjV6b',
#  u'4K1kR94TrMRoznMHBFaa3C',
#  u'3hS5RCp5EE1wUiiE7f8dM1',
#  u'1tvvUJUGzMmprWDmpozXB2',
#  u'45dGKmN6jw7PgK6Dw2rEp2',
#  u'3utIAb67sOu0QHxBE88P1M',
#  u'0bbks4cXwDES54hzcq6Kbm',
#  u'0wqeaDeaKq14IuQESPqBEJ',
#  u'5qi4gxmTIPxlgb9TTLNLrC',
#  u'3gkSe8bayWXWwwhWLOF0f9',
#  u'0qbP1p2jMDkCKXIanfmYtI',
#  u'7FEwZ6YpzrzB3tYr9jtfL7',
#  u'5QsEvml3ZEnISKBEaKueUy',
#  u'4W2SU5ENHBiifn4KnRqgte',
#  u'02JIdsrod3BYucThfUFDUX',
#  u'6swBtLlqbXVbtVFeHZnI5X',
#  u'5INhzSKNRpnvHFDIBk0O4y',
#  u'6EKywtYHtZLAvxyEcqrbE7',
#  u'2E87kSsZd4oSfFOAXNGISJ',
#  u'0mWXrr6HQZUhCQG4JMkT2e',
#  u'4jzea0vyKwayQSb5HBPB36',
#  u'04fAHzTVDZp4Vkb7o54tkt',
#  u'4NDIiA6bvoLK5XRH9wMfde',
#  u'7nNhiYThwK0OwYlHENARC0',
#  u'322E3pHVE4THhniKjNLTY9',
#  u'5q8Dkw2v38Hq9MNsqzLR3E',
#  u'6XqpH9bHj7ODY1z4xI9n7E',
#  u'1bHDvgKt0mqBzTVXWFVg1g',
#  u'2bNxCVI4Fub8BAwr0CQDyd',
#  u'0pnNJJt6DGVWzDSoxxD6Op',
#  u'0L9c2iXFspP8cIJQa1o594',
#  u'5IgCmMRQwLKUAhmVhdlBEd',
#  u'0jkGkwy510cvhy0jYPFme4',
#  u'0qxhucKlrket7p5dw37cpQ',
#  u'6JNCvYkbaD19DZIMo0o9ul',
#  u'0Rg6hoXD1wBiOFZ4pmzoWh',
#  u'3MXC0UDXXepDKGnP7mfMcP',
#  u'5g3kU4aeY2EeVAiV7JNkhK',
#  u'0PJjfWEnMZZtT1J4yV7dx7',
#  u'5e3UWcbvTaF5CJWu81MqlQ',
#  u'3Q0Ngf7Llu1KIteVHRfiXw',
#  u'3CDQ0VITy07A8NDg6CCLf0',
#  u'5oYsXlnI0dpmN32cRDZD6v',
#  u'6BGIYRM9XSFgbQrBtsxuQa',
#  u'51ywMlgjW0YZvAkhaH82zL',
#  u'5AetVSPpFnqBmI9Od499b4',
#  u'3nxotm9m5h0gFhx49Brrc0',
#  u'4DTrKnvkHtwQN6kBu4XXIF',
#  u'0tZqXCvOx44WKqcgEZtIRl',
#  u'6SyPnh5ysbRjmZHIlOKp4r',
#  u'61zQ8XDgOYslFGzfhK823e',
#  u'4Cd01GWLuMTNZhW0DE7cF4',
#  u'3K01q0jtSNHeqx5gs97HH2',
#  u'0dQKabsoT9ojccQgVhLmHN',
#  u'5mGI9cWHzNHGZG8RhzorWT',
#  u'12wSL3tGk3MtbDEhfG7xy3',
#  u'3yXC4ltez6LwFDh5Lk8k7v',
#  u'5JypFayfT1V5OG4xJ8q7jK',
#  u'57SoN3xnEyczFNXJP6roih',
#  u'5yR0Uawj5Srl1O9DSIaLuL',
#  u'1MQVROOLO28PSDUiqQGOFw',
#  u'2Ei07VELTKHy7bJHWxNDRI',
#  u'37lotBTQcBbYI7vEoGsOfg',
#  u'3496JZUnDsR7CG0v02TzE9',
#  u'4qjrCkcVbsYlitCqbBkeKe',
#  u'1pEc2SNzgGvbmvcapQ566n',
#  u'60c0p6GGnuwdKcQnmuM2zC',
#  u'7jSQaXLzpLHjSQTev2krvT',
#  u'7jg5JfizOZSEipnTR6d4Nt',
#  u'5J0d605KKCz4x8zbUKTaPe',
#  u'38uqMByifM0mkjcTbejlyR',
#  u'5ZkAx8zjLiSs1nMmBwJoZS',
#  u'4Rpasa9pT1bEo1MMYNcZDj',
#  u'0njdNc5gqQpJOc8q72rJCe',
#  u'35mtjM30xXExEbkEj3z1a0',
#  u'0Wb0P6PYkCSOPPyd7RSUpD',
#  u'13nqfckcudIAEhycQa5ZTn',
#  u'7eAWmk6IDva2iA0q2Wx9Lv',
#  u'7iocNjLrxPHLl8njgRlv5U',
#  u'25AASoU47mZPdhzxeDp5gP',
#  u'2vC1qUcTJlWO9JQfcaOk9b',
#  u'52Dw5hXeylenurLTKoFJfZ',
#  u'11dxtPJKR4E0wlSr0A0t47',
#  u'1mRBJdpIgc3jZH8C3cN2WV',
#  u'5eEmVNuqo4oKDh9MDeCAmt',
#  u'7bAokm2KfCtoP5JgNXWn5T',
#  u'0MkK9ZTCTrs2Xh6d1XTPfp',
#  u'2kSZ6pNjGuyVmUnF1sVhNc',
#  u'7jjepkxo9Znkw5B4NNbFlv',
#  u'2ZTCl6wQMDSMfY4s8GHZdj',
#  u'5rfkxoAOtn1WfZ5wa4J4bq',
#  u'5ecZWU5uQOiCVSnPxBZNmT',
#  u'3gH3AxHKptBuYVcJilLCeR',
#  u'0IyTsEF01ElREZbmq9hOnK',
#  u'2wQN8tMYOHStr6Q61jh0IK',
#  u'1D14PtAZlLWiBvxqngjrYp',
#  u'3cgnaW34QpP1Y8Wvoz4D56',
#  u'1SDYD25CrItJZ5nFIa2FxQ',
#  u'1nxqFTGZzZoVfqVzB2d0Oe',
#  u'6tlMa6UVin2L6yEe2rxb0K',
#  u'4bb2UdCvi9LynD4rWvE06T',
#  u'7gszEHRkBhgWxz4ehSe0lr',
#  u'2ZwdchTTbQgSsbJYnf7C6i',
#  u'1VG1Bswylv2FtgddxddIkQ',
#  u'7Hd2eFMAm44IcrXuGIsvqt',
#  u'4nCOKtVT623uOCgXyxLqWw',
#  u'5wkeuyd8h0oEbfE1Zop8Bt',
#  u'09HBvmj0dUeQYHGbKJefR5',
#  u'7MG5A5HdsYjlHNjFp6Z7ec',
#  u'0EvfIJmTPccLT0IM2UGC1G',
#  u'50MQO0AAOizDBOErF0rqUN',
#  u'3bSq5OpEWmLK1o8F7saR2F',
#  u'5Au8ObNQvrwFVEgGqQQL6D',
#  u'2z1SaJJSPpLDQJphaESqKC',
#  u'3RcTV0VBkSwzHNMghOmRbm',
#  u'08QaHlMPWuO5PUxjl61bXn',
#  u'5HDU7GEOPcsic0kHXbkzZE',
#  u'5QbWc5ipIn02XePjT0Tvaf',
#  u'47oZeMBl3jRklleSE7YxcT',
#  u'1YekSxsAlGlYvm9zjLsKdh',
#  u'4CeJ9kIun8myfIzuj5Yqzp',
#  u'5IzYCxKMZs0QDXRyTwH4dU',
#  u'5795tkQ1pTLZ2D3jctqhdQ',
#  u'1RI7mhYWlGj6IvdBc2lGnY',
#  u'72V7HVj71eNXogp7y4gfVw',
#  u'6IOnUNpll37ONAgshDwa5B',
#  u'1Z0FVMu8zaXEVjNitnIk1Q',
#  u'1Gzlrm9Hq8b05TMYXgZ0Wq',
#  u'27KKViR4AX2zaJDTQX6sWE',
#  u'0huDTnkXO0LJZcAHjotWYz',
#  u'6miK1DMb1WONHzH1jh5PLk',
#  u'58HmmJt3lCEeAbJ0rm7mqT',
#  u'1ZW3EVkByv6UgGxigVS8lF',
#  u'59oPOJ9bYDhWAKNW3gaSPS',
#  u'3s6nfqfT6kyLBT10vs0M4l',
#  u'6xLPSFeiQyFvta93OKngnB',
#  u'7k35t6uy5r5W1YDWAYbps0',
#  u'4H4R3ovWugoDYtGFB2V5s0',
#  u'44e84JcEUfOs9cNGu8nwU5',
#  u'1mD4ResONwh19VNAQpwPCh',
#  u'5Q0Nhxo0l2bP3pNjpGJwV1',
#  u'4dsoM6q2kDJhpYB4IOL0Od',
#  u'7lPxGs556PD8H3bUd9LzHp',
#  u'004skCQeDn1iLntSom0rRr',
#  u'5hK2Ks25jW6aMmUAHpAN3F',
#  u'7I80zTBTDNnbOiJQ0JLjZr',
#  u'79oesFYaS2VT39ShdA19u9',
#  u'3xtJ0ELyByUQ64MMnny6U8',
#  u'6hr58jjgkAH865kTng8p63',
#  u'3TcL0dyCMyr0kyTTc4NLgI',
#  u'1HwpWwa6bnqqRhK8agG4RS',
#  u'7qMriHg2jWHPQW9sdhLPZG',
#  u'0M9VqYG0wVun054JIdwFO8',
#  u'4LjOKmZbfhx2uOEQopXgcn',
#  u'0tn5y45WN14Izw06z8Gk51',
#  u'1y6Y28gA3mNHSs7RDLrDKs',
#  u'75a5fcQSduYyC93gXtgGhk',
#  u'6BfOhpHADzrvKN2kMPTMPv',
#  u'2ziVTVizQdVNC2QhQhNGvg',
#  u'5Plb8xps8VZRF2sXlrPi3Q',
#  u'3je1pkjiD7TLndoW6jqjoj',
#  u'6bqgsANhiAYKiNq0wgcxSL',
#  u'407YIDqsL4S3ZJ2BOFg4P0',
#  u'0DcxLrvPPkOQtytolEC5ZI',
#  u'49OEaKOzIgXfOD55bSGSeG',
#  u'6v10gld4H0wNPN9LqNqAaL',
#  u'47d2mzkc3bPUD93NB0gKLR',
#  u'5v5BB1IDbjVFzlr8drWsTc',
#  u'73qbBlEAcm2HfnAaSnP1II',
#  u'2adTfABiJJQpZWlujYO3Qo',
#  u'33e8JtboPPzbzCsCqfPnr9',
#  u'5OwAflm8WHaa4Z6sMmZKWz',
#  u'3rcXcJT6Uwg1ojuCdPRjeJ',
#  u'1YaVmBh7EAeR54FIjuFcb5',
#  u'4GhI2lrDJwwLXEGSrVrQGG',
#  u'3xD7IyUPTR4Dq5VBowzjr3',
#  u'2CE6ap3LeMjWlrwS1c6ZAn',
#  u'2sggS6A5pA0KWaleWsHzmL',
#  u'0oe0UYSKAESBUR12I1ESXQ',
#  u'08kCck8nAJJEmxg0gXaJot',
#  u'05ZwvpRTSpE2fxnexxDIRq',
#  u'5bIaUFqwok97vCXAoTqFkj',
#  u'1rM0CnyUiiw6A9CHJRXjZA',
#  u'1vWofkfHYG9w1fQ4DFputC',
#  u'6AYCFow2O5wPgGAXr781XO',
#  u'35PfuPS1QqlyDhcvQOan4o',
#  u'07XDfjpXYL8T0wOGMk81Xr',
#  u'3oFSbVCS8conK9GwJWOSH6',
#  u'0YlqJkfuox9LpJ5uW3NPM8',
#  u'0v4D8TdVoYN6lDVdZpwz8r',
#  u'1QkJBQnCv81ef7gyWMDL3Q',
#  u'1eM1TAhv39wg4LY7XmtqoL',
#  u'39zODpVtRvghMyfNjZ3BVK',
#  u'5qiWQq9tPjMDNpd1knSoZ0',
#  u'22GeNHLRDo55WPE1pzCau0',
#  u'6WydLaR6XhF2tsb7cDqKMH',
#  u'7jovA40dNwGHwg8wjYK3Ku',
#  u'73eC56fk6tKNvO6Aq5UDZg',
#  u'3XuynAYyLtvJrI2NvVXu6Z',
#  u'0Q2y7Amx3vHz5Jqa7TFEYE',
#  u'3FRuUuqmFDk3BYHaDzAjTI',
#  u'6kkFjjMbO9EL1YxNt8BKm3',
#  u'5q4uMmYpzS0zduoBoSPKsU',
#  u'4rm1U6PBUaGs2nZztwckzf',
#  u'7vQOLuR38q0sPtEE88sbL5',
#  u'5snZk2OdvTQdSaEoXUiZSD',
#  u'5lHo4CVqgcRQGoDlj8GcKu',
#  u'1b4QmuIHiO4IR2JgnH3p0s',
#  u'2l3imSkvdlMxEzCLiZXLcM',
#  u'6oOJU64nYMU4ljUiMCGeHe',
#  u'2jXxUK7a6zVPStFSCZqe4G',
#  u'2k0uuop6Kik4p4tswCUruW',
#  u'3Kc1W7xl7dZ2bEnoKHbnBt',
#  u'6YufqZwFe2U4mxCy3B1xsC',
#  u'6ix0SApsNi4TAZE5zDTfMj',
#  u'4CiIdZ7Eg4zzrifatjZDWG',
#  u'4Y8ffsPwnVRkFEUqxkQAyz',
#  u'4s5373PurC9WnEMRHtBWdP',
#  u'57EXEeSOfst4DV0ptqPAS7',
#  u'15NNe4V26FOiwagrNb4lbS',
#  u'6Rec3bXEJzwBdr9RKs1hQ7',
#  u'3ChNbqbiPteCoYtufO79qw',
#  u'7CY1MXWnjsQMqm2OcOUnbM',
#  u'6AFBz24yIN6mlKpkOeGHzc',
#  u'4WK4t3FTPX9ZEUQoIUDD82',
#  u'20GJ94KHYugkULE81t7t4e',
#  u'1b6Spq4MiEzShOBQLtEhWe',
#  u'537mRuCCiKQNFlN1vdSl1k',
#  u'5SfdvzJpx8e8AAL4VDlRWp',
#  u'6gDPf8eJIRQ73rUktH17P3',
#  u'46hu9JtTWN8DshperdNaUU',
#  u'0OAnOHYJxsMtMTZ6vf14xh',
#  u'0VRh0HgB1RsgqjH7YswsJK',
#  u'5QLLhvfPdnls7G97VfJYiJ',
#  u'2HeLqRgQRttQE16abLHfR5',
#  u'6C7NLheYmP4zintC6OOXzf',
#  u'099QlSujdXkd9DCwAh2fgX',
#  u'47OC0Xl9TIijX4gkafSX1G',
#  u'1nm4vrhyOvwJX5MJRlLAps',
#  u'0g3HJztr5rZHcLVJ9CUmVJ',
#  u'3pCs3XEKyltrLH9CPYTi2X',
#  u'7gEtGimCKSALyh1OKV58vB',
#  u'72hNRNaNyeeAVKvYGQNgpp',
#  u'1iSoEZbLfJ9QzwC5BQco35',
#  u'7yKQz8za5CAzV3t98CKota',
#  u'14QnVZy8GJ32CkXvUKpgse',
#  u'1ypaTvlkJjmMeGhFx7D43u',
#  u'7joekz6jMhNuj3EQhyKsm2',
#  u'0lYS1tJg3r6ATe9bRPB0Hu',
#  u'2WzheJclGO0IeUU68hYrTa',
#  u'6osFf87BM0y0AFd5nSRjzr',
#  u'5pyTW9ph8A0ZSx7hzpSNge',
#  u'5NdwMwDT64WOqpi6XbOtqP',
#  u'0ERKcBLTUnY1Cvb6i5fBu2',
#  u'10xcIQQEJSEIOgG1HvS3t9',
#  u'1XjPTbOPJvd2zYbaSyHQlM',
#  u'6xNwKNYZcvgV3XTIwsgNio',
#  u'076BNCkQ5lhc0V3sep0uIY',
#  u'30J2aUXkTp9vsGWH3tegca',
#  u'6zUEASOe0Iko9KFT5t8J5D',
#  u'7MpTAgJdkjCNPUWK3PkYpf',
#  u'6tfYyaiCzvmhOP525jGXNc',
#  u'0LMQvt6yAGggdowj8hazNy',
#  u'27kN2ZJYpfYjC55ERlAqAY',
#  u'3XHdk0KVdgO2sRH5dqibFB',
#  u'1Zx5Y46u3v32jRRIWtzQKN',
#  u'2q3X0uc2XpGruqitKOm3xa',
#  u'38J7vmkCIvTtnP6Zd5bnuU',
#  u'5Yl2MFlben2pLcEUaKrDyJ',
#  u'58iuuMeVzgGhCwhnx3zBAP',
#  u'7dB5NHrlkkAH4INIxySjWZ',
#  u'63OHQ5zebkOIllF9O3372c',
#  u'58NaxllapZyj9yUXl0WjBU',
#  u'5mTIzzIv60E2B034cZs70l',
#  u'6mQlq4Fd8C1uBbnwdkkXYm',
#  u'4Xt0OKNJtbyqx5GEX2XpVF',
#  u'2RHdAL4ILYBMXYufbNi0kH',
#  u'33RJ3P6wc0B0FIyDalhNTv',
#  u'3tg5qQYoC7FarLuEZchaZm',
#  u'5bzzu4VL5Jd4VoTU4MYkHI',
#  u'4Fzd0BCMixW1jqpOLiBvRe',
#  u'7qSlHXxWZyxmxJ82IVMYyu',
#  u'2sDIU2PX98cWQGEpsX7VC6',
#  u'0grxFyenxR3OYMdIhxRzJ6',
#  u'4He7bzKBaiu7CRz4wGkZzx',
#  u'2f6s0AcBRBE0vIOU0NMdXw',
#  u'26LMlybHegFJie3Gj2a7eD',
#  u'2FWmsLddIpZDE6c9EhaZO6',
#  u'1iVkEiZS6ijZ76KeMsrXG6',
#  u'1AzUYCVWObAIKGP1caaGif',
#  u'71GVkB7fIwkVoYjTh6VNav',
#  u'3hsX3NOX05cGSjsrBJ2phQ',
#  u'4jadyA9N53rvVjy6KjKAgT',
#  u'208rmXdjs6mywkQRQw0xni',
#  u'32QxzmGau0iwznufUriSv4',
#  u'3T1SnpyLk328tKCV6qsnmX',
#  u'6x7ifZSwVBo7vHagtWPb8E',
#  u'4nOpE2Lp91gHVAJFc6OQD3',
#  u'4HevsNZM3BVNBqZTAIXlA2',
#  u'6pm1oZnmPYzSq66AN301hM',
#  u'1c7bTtnrdFONK1RAmsz2nX',
#  u'7EA9SlGReyET1cYHIeFbIH',
#  u'1DOK4imxjjUaPWxUQUqHL1',
#  u'0VEJcJRJEAhkqIFYjslfwZ',
#  u'0MQcZFYpZkH7TEN5WAKa6S',
#  u'1jypmXUJgxWKWJZdDsJiXQ',
#  u'5RhxBpoCwX2vLBcSJzYa5j',
#  u'0O81GMQ8IBB1ZDjVHyNYQp',
#  u'3emD3Ss9xc1hldBIkYhQ6C',
#  u'0laYHRpNTS6i8FXdupHkJ4',
#  u'2DMOjHafRx0V2tgiZv3QoQ',
#  u'5dDLa2HhSwqoQUULN4Llsd',
#  u'75fi0OeQnaAAdCtC8Ob9rP',
#  u'20o0LkrQlFoyket5tYHGid',
#  u'32vSMuRMwTf31DfVqLFJaC',
#  u'3Gbq2jcKXAOAPQTz06sNAi',
#  u'1qsN5cpqU6quWtL9lgyA1v',
#  u'58MfY2ldjq25ei7fRRWLae',
#  u'3oEllCjRbaRJrZKtZVLsDJ',
#  u'12RONGiPBjbbg78T4c43JY',
#  u'7ERDHfLXilsatA9KT8kWgk',
#  u'6p8lCOvTbSI4eijtyw6pW4',
#  u'0PQ8MsAxETdEW3LigpDujI',
#  u'4D7qjCFBUSleoTGevgVZxn',
#  u'4lS2803hVm5ZvKp4bzKIF0',
#  u'3uz0oJpuhXnQ1KwciBbpNR',
#  u'5L5kbRwOUvXqOAbemwwYMZ',
#  u'0yclrJ4QJquwTXgyr35F1Q',
#  u'6CCojAcrSWs6f6tfIZocHP',
#  u'3Qa3DloYwXHjp0zt7GP4vi',
#  u'06ngjaiEea4jvIcAIcxcGr',
#  u'2ZnXIAkOUkQy8jrFqzGbox',
#  u'2bO8XZcJRHr8PhnKqxYuXD']
